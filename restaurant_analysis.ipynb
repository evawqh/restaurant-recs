# %%
# import pandas for data analysis
import pandas as pd

# %%
# read in two csv files containing restaurant recommendations from Xiaohongshu (my Chinese social media) and TimeOut Magazine.
xhs_df=pd.read_csv("data/eva-data-studio-project-01 - Xiaohongshu.csv")
to_df=pd.read_csv("data/eva-data-studio-project-01 - TimeOut.csv")

# %%
# Check through the name column TimeOut and Xiaohongshu 
# and make a new df of restaurants that overlap in these two lists
overlap_df=pd.merge(to_df, xhs_df, how="inner", on="Name", copy=False)

# %%
# Drop duplicate columns of coordinates and cuisine and standardize column names
overlap_df=overlap_df.drop(columns=["Coordinates_y", "Cuisine_y"])
overlap_df.rename({"Coordinates_x": "Coordinates", "Cuisine_x": "Cuisine"}, axis=1, inplace=True)

# %%
overlap_df
# Out:
#                       Name          Coordinates           Cuisine
# 0          Hutong New York  40.76190, -73.96758  Northern Chinese
# 1  Szechuan Mountain House  40.73937, -73.98798        Sichuanese
# 2               Hao Noodle  40.73382, -74.00001        Sichuanese
# 3           Congee Village  40.71883, -73.99035         Cantonese

# %%
# A list of restaurant names mentioned in both
overlap_names=overlap_df.Name.to_list()
overlap_names
# Out:
# ['Hutong New York', 'Szechuan Mountain House', 'Hao Noodle', 'Congee Village']

# %%
# deleting the xhs restaurants also mentioned in timeout
for overlap_name in overlap_names:
    xhs_df = xhs_df[xhs_df.Name!=overlap_name]
xhs_df
# Out:
#                              Name          Coordinates               Cuisine
# 0                   Shoo Long Kan  40.76047, -73.83350    Sichuanese Hot pot
# 1                            Chai  40.76123, -73.98974           Beijingnese
# 3                        Antidote  40.71686, -73.96587            Sichuanese
# 4                            Uluh  40.72948, -73.98657            Sichuanese
# 5                  Kong Sihk Tong  40.71565, -73.99813             Cantonese
# 6                           Bo Ky  40.71591, -73.99867             Cantonese
# 7                Yin Ji Chang Fen  40.71588, -73.99930             Cantonese
# 8                 CheLi Manhattan  40.72939, -73.98869          Zhejiangnese
# 9                       Dun Huang  40.81120, -73.95823  Northwestern Chinese
# 10         Taiwan Pork Chop House  40.71441, -73.99803             Taiwanese
# 11               Haidilao Hot Pot  40.76113, -73.82781    Sichuanese Hot pot
# 13              August Gatherings  40.71926, -74.00112             Cantonese
# 14                         Le Sia  40.76091, -73.99127               Chinese
# 16             Peppercorn Station  40.75327, -73.98503            Sichuanese
# 18                       Chef Tan  40.72969, -73.98790   Sichuanese Hunanese
# 19                       Alley 41  40.75929, -73.82798            Sichuanese
# 20       Nurlan Uyghur Restaurant  40.75169, -73.82586                Uyghur
# 21                   Ju Shui Yuan  40.75946, -73.82674  Northeastern Chinese
# 22   900 Du Chuan Gong Restaurant  40.75217, -73.82675  Northeastern Chinese
# 23           Red House Restaurant  40.76127, -73.83304          Shanghainese
# 24  Deng Ji Yunnan Guoqiao Mixian  40.75887, -73.83155             Yunnanese
# 25                     Xi Top BBQ  40.76266, -73.81513  Northeastern Chinese
# 26                    Followsoshi  40.75863, -73.83067      Northern Chinese
# 27                        OK Ryan  40.75618, -73.83381             Taiwanese
# 28              Chongqing Lao Zao  40.76123, -73.83294    Sichuanese Hot pot

# %%
# deleting the timeout restaurants also mentioned in xhs
for overlap_name in overlap_names:
    to_df = to_df[to_df.Name!=overlap_name]
to_df
# Out:
#                          Name          Coordinates               Cuisine
# 0          Nom Wah Tea Parlor  40.71467, -73.99822             Cantonese
# 2               Grand Sichuan  40.74749, -74.00096            Sichuanese
# 3        DAXI Sichuan Cuisine  40.75950, -73.82906            Sichuanese
# 4                Mala Project  40.72836, -73.98555            Sichuanese
# 5                     RedFarm  40.73881, -74.00606        Chinese fusion
# 6         Great NY Noodletown  40.71517, -73.99711             Cantonese
# 7          Xi'an Famous Foods  40.71584, -73.99716  Northwestern Chinese
# 8            456 New Shanghai  40.71636, -73.99828          Shanghainese
# 9                   Lan Sheng  40.75168, -73.98833            Sichuanese
# 10             Pacific Palace  40.63831, -74.00615             Cantonese
# 11     Yun Nan Flavour Garden  40.64021, -74.00460             Yunnanese
# 12       Han Dynasty Brooklyn  40.69603, -73.98229            Sichuanese
# 13              Spicy Village  40.71718, -73.99346              Henanese
# 15          Peking Duck House  40.72620, -74.00034           Beijingnese
# 16                     Wo Hop  40.71440, -73.99892      American Chinese
# 17              Little Pepper  40.78302, -73.84598            Sichuanese
# 18                Hunan Slurp  40.72688, -73.98566              Hunanese
# 19             New World Mall  40.75950, -73.82920               Chinese
# 22  Tasty Hand-Pulled Noodles  40.71426, -73.99787      Northern Chinese
# 23             99 Favor Taste  40.73228, -73.99310            Sichuanese
# 24         Birds of a Feather  40.71451, -73.96056            Sichuanese
# 25                 Spicy Moon  40.73007, -73.99844      Vegan Sichuanese
# 26    Nan Xiang Xiao Long Bao  40.75974, -73.83245          Shanghainese
# 27              Atlas Kitchen  40.80351, -73.96678   Sichuanese Hunanese
# 28             Fried Dumpling  40.71469, -73.99925               Chinese

# %%
xhs_df[["Latitude", "Longitude"]] = xhs_df.Coordinates.str.split(",", expand=True)

# %%
to_df[["Latitude", "Longitude"]] = to_df.Coordinates.str.split(",", expand=True)

# %%
overlap_df[["Latitude", "Longitude"]] = overlap_df.Coordinates.str.split(",", expand=True)

# %%
xhs_df.to_csv("xiaohongshu_unique.csv", index=False)
to_df.to_csv("timeout_unique.csv", index=False)

# %%
overlap_df.to_csv("overlap.csv", index=False)

# %%
xhs_df["source"] = "Xiaohongshu"
to_df["source"] = "TimeOut Magazine"
overlap_df["source"] = "Recommended by Both"

# %%
all_df = pd.concat([xhs_df, to_df, overlap_df], ignore_index=False)

# %%
all_df
# Out:
#                              Name          Coordinates               Cuisine  \
# 0                   Shoo Long Kan  40.76047, -73.83350    Sichuanese Hot pot
# 1                            Chai  40.76123, -73.98974           Beijingnese
# 3                        Antidote  40.71686, -73.96587            Sichuanese
# 4                            Uluh  40.72948, -73.98657            Sichuanese
# 5                  Kong Sihk Tong  40.71565, -73.99813             Cantonese
# 6                           Bo Ky  40.71591, -73.99867             Cantonese
# 7                Yin Ji Chang Fen  40.71588, -73.99930             Cantonese
# 8                 CheLi Manhattan  40.72939, -73.98869          Zhejiangnese
# 9                       Dun Huang  40.81120, -73.95823  Northwestern Chinese
# 10         Taiwan Pork Chop House  40.71441, -73.99803             Taiwanese
# 11               Haidilao Hot Pot  40.76113, -73.82781    Sichuanese Hot pot
# 13              August Gatherings  40.71926, -74.00112             Cantonese
# 14                         Le Sia  40.76091, -73.99127               Chinese
# 16             Peppercorn Station  40.75327, -73.98503            Sichuanese
# 18                       Chef Tan  40.72969, -73.98790   Sichuanese Hunanese
# 19                       Alley 41  40.75929, -73.82798            Sichuanese
# 20       Nurlan Uyghur Restaurant  40.75169, -73.82586                Uyghur
# 21                   Ju Shui Yuan  40.75946, -73.82674  Northeastern Chinese
# 22   900 Du Chuan Gong Restaurant  40.75217, -73.82675  Northeastern Chinese
# 23           Red House Restaurant  40.76127, -73.83304          Shanghainese
# 24  Deng Ji Yunnan Guoqiao Mixian  40.75887, -73.83155             Yunnanese
# 25                     Xi Top BBQ  40.76266, -73.81513  Northeastern Chinese
# 26                    Followsoshi  40.75863, -73.83067      Northern Chinese
# 27                        OK Ryan  40.75618, -73.83381             Taiwanese
# 28              Chongqing Lao Zao  40.76123, -73.83294    Sichuanese Hot pot
# 0              Nom Wah Tea Parlor  40.71467, -73.99822             Cantonese
# 2                   Grand Sichuan  40.74749, -74.00096            Sichuanese
# 3            DAXI Sichuan Cuisine  40.75950, -73.82906            Sichuanese
# 4                    Mala Project  40.72836, -73.98555            Sichuanese
# 5                         RedFarm  40.73881, -74.00606        Chinese fusion
# 6             Great NY Noodletown  40.71517, -73.99711             Cantonese
# 7              Xi'an Famous Foods  40.71584, -73.99716  Northwestern Chinese
# 8                456 New Shanghai  40.71636, -73.99828          Shanghainese
# 9                       Lan Sheng  40.75168, -73.98833            Sichuanese
# 10                 Pacific Palace  40.63831, -74.00615             Cantonese
# 11         Yun Nan Flavour Garden  40.64021, -74.00460             Yunnanese
# 12           Han Dynasty Brooklyn  40.69603, -73.98229            Sichuanese
# 13                  Spicy Village  40.71718, -73.99346              Henanese
# 15              Peking Duck House  40.72620, -74.00034           Beijingnese
# 16                         Wo Hop  40.71440, -73.99892      American Chinese
# 17                  Little Pepper  40.78302, -73.84598            Sichuanese
# 18                    Hunan Slurp  40.72688, -73.98566              Hunanese
# 19                 New World Mall  40.75950, -73.82920               Chinese
# 22      Tasty Hand-Pulled Noodles  40.71426, -73.99787      Northern Chinese
# 23                 99 Favor Taste  40.73228, -73.99310            Sichuanese
# 24             Birds of a Feather  40.71451, -73.96056            Sichuanese
# 25                     Spicy Moon  40.73007, -73.99844      Vegan Sichuanese
# 26        Nan Xiang Xiao Long Bao  40.75974, -73.83245          Shanghainese
# 27                  Atlas Kitchen  40.80351, -73.96678   Sichuanese Hunanese
# 28                 Fried Dumpling  40.71469, -73.99925               Chinese
# 0                 Hutong New York  40.76190, -73.96758      Northern Chinese
# 1         Szechuan Mountain House  40.73937, -73.98798            Sichuanese
# 2                      Hao Noodle  40.73382, -74.00001            Sichuanese
# 3                  Congee Village  40.71883, -73.99035             Cantonese
#
#     Latitude   Longitude               source
# 0   40.76047   -73.83350          Xiaohongshu
# 1   40.76123   -73.98974          Xiaohongshu
# 3   40.71686   -73.96587          Xiaohongshu
# 4   40.72948   -73.98657          Xiaohongshu
# 5   40.71565   -73.99813          Xiaohongshu
# 6   40.71591   -73.99867          Xiaohongshu
# 7   40.71588   -73.99930          Xiaohongshu
# 8   40.72939   -73.98869          Xiaohongshu
# 9   40.81120   -73.95823          Xiaohongshu
# 10  40.71441   -73.99803          Xiaohongshu
# 11  40.76113   -73.82781          Xiaohongshu
# 13  40.71926   -74.00112          Xiaohongshu
# 14  40.76091   -73.99127          Xiaohongshu
# 16  40.75327   -73.98503          Xiaohongshu
# 18  40.72969   -73.98790          Xiaohongshu
# 19  40.75929   -73.82798          Xiaohongshu
# 20  40.75169   -73.82586          Xiaohongshu
# 21  40.75946   -73.82674          Xiaohongshu
# 22  40.75217   -73.82675          Xiaohongshu
# 23  40.76127   -73.83304          Xiaohongshu
# 24  40.75887   -73.83155          Xiaohongshu
# 25  40.76266   -73.81513          Xiaohongshu
# 26  40.75863   -73.83067          Xiaohongshu
# 27  40.75618   -73.83381          Xiaohongshu
# 28  40.76123   -73.83294          Xiaohongshu
# 0   40.71467   -73.99822     TimeOut Magazine
# 2   40.74749   -74.00096     TimeOut Magazine
# 3   40.75950   -73.82906     TimeOut Magazine
# 4   40.72836   -73.98555     TimeOut Magazine
# 5   40.73881   -74.00606     TimeOut Magazine
# 6   40.71517   -73.99711     TimeOut Magazine
# 7   40.71584   -73.99716     TimeOut Magazine
# 8   40.71636   -73.99828     TimeOut Magazine
# 9   40.75168   -73.98833     TimeOut Magazine
# 10  40.63831   -74.00615     TimeOut Magazine
# 11  40.64021   -74.00460     TimeOut Magazine
# 12  40.69603   -73.98229     TimeOut Magazine
# 13  40.71718   -73.99346     TimeOut Magazine
# 15  40.72620   -74.00034     TimeOut Magazine
# 16  40.71440   -73.99892     TimeOut Magazine
# 17  40.78302   -73.84598     TimeOut Magazine
# 18  40.72688   -73.98566     TimeOut Magazine
# 19  40.75950   -73.82920     TimeOut Magazine
# 22  40.71426   -73.99787     TimeOut Magazine
# 23  40.73228   -73.99310     TimeOut Magazine
# 24  40.71451   -73.96056     TimeOut Magazine
# 25  40.73007   -73.99844     TimeOut Magazine
# 26  40.75974   -73.83245     TimeOut Magazine
# 27  40.80351   -73.96678     TimeOut Magazine
# 28  40.71469   -73.99925     TimeOut Magazine
# 0   40.76190   -73.96758  Recommended by Both
# 1   40.73937   -73.98798  Recommended by Both
# 2   40.73382   -74.00001  Recommended by Both
# 3   40.71883   -73.99035  Recommended by Both

# %%
all_df.to_csv("all_res.csv", index=False)
